# %%
import pandas as pd
import os
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Embedding, Dense, Flatten
from keras.callbacks import Callback
import matplotlib.pyplot as plt

###
# Get the GoogleNews-vectors-negative300.bin into the google folder
# Get the binary into readable format
###
# https://stackoverflow.com/questions/27324292/convert-word2vec-bin-file-to-text
# from gensim.models.keyedvectors import KeyedVectors
# model = KeyedVectors.load_word2vec_format('./google/GoogleNews-vectors-negative300.bin', binary=True)
# model.save_word2vec_format('./google/GoogleNews-vectors-negative300.txt', binary=False)


# https://machinelearningmastery.com/use-word-embedding-layers-deep-learning-keras/
embedding_file = open('./google/GoogleNews-vectors-negative300_lite.txt')
embedding_file.readline()
embedding_indices = dict()
for line in embedding_file:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype=np.float32)
    embedding_indices[word] = coefs
embedding_file.close()


def get_model(e):
    model = Sequential()
    model.add(e)
    model.add(Dense(64, activation='relu'))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer="adam", loss="binary_crossentropy", metrics=['acc'])

    print(model.summary())
    return model


class EpochHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.accs = []

    def on_epoch_end(self, epoch, logs={}):
        self.losses.append(logs.get('loss'))
        self.accs.append(logs.get('acc'))
        return


accs = list()
losses = list()

dataset_base = "lexical_entailment"
datasets = ["baroni2012", "bless2011", "kotlerman2010", "levy2014", "turney2014"]
test = "data_lex_test.tsv"
train = "data_lex_train.tsv"
val = "data_lex_val.tsv"

for chosen_dataset in range(len(datasets)):
    glob = pd.read_csv(
        os.path.join(dataset_base, datasets[chosen_dataset], 'data.tsv')
        , sep='\t', header=None)

    glob_text_np = np.array(glob.loc[:, 0:1]).flatten()
    glob_text_uniq = list(set(glob_text_np))
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(glob_text_uniq)
    vocab_size = len(tokenizer.word_index) + 1

    ###
    # Load weights into keras readable format
    ###
    # https://machinelearningmastery.com/use-word-embedding-layers-deep-learning-keras/
    num_words_found = 0
    embedding_matrix = np.zeros((vocab_size, 300))
    for word, i in tokenizer.word_index.items():
        embedding_vector = embedding_indices.get(word)
        if embedding_vector is not None:
            num_words_found+=1
            embedding_matrix[i] = embedding_vector

    print("%d words found out of %d in the %d item long embedding corpus."%
          (num_words_found, vocab_size, len(embedding_indices)))
    ###
    # Setting up the model
    ###

    embedding1 = Embedding(vocab_size, 300, weights=[embedding_matrix], input_length=2, trainable=False)
    model1 = get_model(embedding1)

    embedding2 = Embedding(vocab_size, 300, input_length=2, trainable=True)
    model2 = get_model(embedding2)

    ###
    # Train the model
    ###

    train_glob = pd.read_csv(
        os.path.join(dataset_base, datasets[chosen_dataset], train)
        , sep='\t', header=None)

    val_glob = pd.read_csv(
        os.path.join(dataset_base, datasets[chosen_dataset], val)
        , sep='\t', header=None)

    test_glob = pd.read_csv(
        os.path.join(dataset_base, datasets[chosen_dataset], test)
        , sep='\t', header=None)

    train_X = np.array(train_glob.loc[:, 0:1])
    train_X = np.array([[tokenizer.texts_to_sequences([txt])[0][0] for txt in row] for row in train_X]).squeeze()
    train_Y = np.array(train_glob.loc[:, 2])
    train_Y = train_Y * 1

    val_X = np.array(val_glob.loc[:, 0:1])
    val_X = np.array([[tokenizer.texts_to_sequences([txt])[0][0] for txt in row] for row in val_X]).squeeze()
    val_Y = np.array(val_glob.loc[:, 2])
    val_Y = val_Y * 1

    test_X = np.array(test_glob.loc[:, 0:1])
    test_X = np.array([[tokenizer.texts_to_sequences([txt])[0][0] for txt in row] for row in test_X]).squeeze()
    test_Y = np.array(test_glob.loc[:, 2])
    test_Y = test_Y * 1

    models = [model1, model2]
    testset_accs = list()
    testset_losses = list()
    for i, model in enumerate(models):
        history = EpochHistory()
        print("## Training model #%d ##" % i)
        model.fit(train_X, train_Y, epochs=100, validation_data=(val_X, val_Y), callbacks=[history], verbose=0)

        testset_accs.append(history.accs)
        testset_losses.append(history.losses)

        print("## Testing model #%d ##" % i)
        t_loss, t_acc = model.evaluate(test_X, test_Y, verbose=0)
        print("Test Results: loss=%f, acc=%f" % (t_loss, t_acc))

    accs.append(testset_accs)
    losses.append(testset_losses)
# Out:
# /home/norbi/miniconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 1422 words found out of 1479 in the 149999 item long embedding corpus.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 2, 300)            443700
# _________________________________________________________________
# dense_1 (Dense)              (None, 2, 64)             19264
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 463,093
# Trainable params: 19,393
# Non-trainable params: 443,700
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 2, 300)            443700
# _________________________________________________________________
# dense_3 (Dense)              (None, 2, 64)             19264
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 463,093
# Trainable params: 463,093
# Non-trainable params: 0
# _________________________________________________________________
# None
# ## Training model #0 ##
# ## Testing model #0 ##
# Test Results: loss=1.421224, acc=0.688433
# ## Training model #1 ##
# ## Testing model #1 ##
# Test Results: loss=1.050399, acc=0.455224
# 4834 words found out of 5623 in the 149999 item long embedding corpus.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 2, 300)            1686900
# _________________________________________________________________
# dense_5 (Dense)              (None, 2, 64)             19264
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,706,293
# Trainable params: 19,393
# Non-trainable params: 1,686,900
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 2, 300)            1686900
# _________________________________________________________________
# dense_7 (Dense)              (None, 2, 64)             19264
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,706,293
# Trainable params: 1,706,293
# Non-trainable params: 0
# _________________________________________________________________
# None
# ## Training model #0 ##
# ## Testing model #0 ##
# Test Results: loss=0.526218, acc=0.921096
# ## Training model #1 ##
# ## Testing model #1 ##
# Test Results: loss=0.307565, acc=0.921644
# 1119 words found out of 1153 in the 149999 item long embedding corpus.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 2, 300)            345900
# _________________________________________________________________
# dense_9 (Dense)              (None, 2, 64)             19264
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 365,293
# Trainable params: 19,393
# Non-trainable params: 345,900
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 2, 300)            345900
# _________________________________________________________________
# dense_11 (Dense)             (None, 2, 64)             19264
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 365,293
# Trainable params: 365,293
# Non-trainable params: 0
# _________________________________________________________________
# None
# ## Training model #0 ##
# ## Testing model #0 ##
# Test Results: loss=1.724020, acc=0.676329
# ## Training model #1 ##
# ## Testing model #1 ##
# Test Results: loss=0.676166, acc=0.665056
# 456 words found out of 760 in the 149999 item long embedding corpus.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 2, 300)            228000
# _________________________________________________________________
# dense_13 (Dense)             (None, 2, 64)             19264
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 247,393
# Trainable params: 19,393
# Non-trainable params: 228,000
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 2, 300)            228000
# _________________________________________________________________
# dense_15 (Dense)             (None, 2, 64)             19264
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 247,393
# Trainable params: 247,393
# Non-trainable params: 0
# _________________________________________________________________
# None
# ## Training model #0 ##
# ## Testing model #0 ##
# Test Results: loss=0.350250, acc=0.905863
# ## Training model #1 ##
# ## Testing model #1 ##
# Test Results: loss=0.371061, acc=0.928308
# 2090 words found out of 2165 in the 149999 item long embedding corpus.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 2, 300)            649500
# _________________________________________________________________
# dense_17 (Dense)             (None, 2, 64)             19264
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 668,893
# Trainable params: 19,393
# Non-trainable params: 649,500
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_10 (Embedding)     (None, 2, 300)            649500
# _________________________________________________________________
# dense_19 (Dense)             (None, 2, 64)             19264
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 668,893
# Trainable params: 668,893
# Non-trainable params: 0
# _________________________________________________________________
# None
# ## Training model #0 ##
# ## Testing model #0 ##
# Test Results: loss=1.443328, acc=0.637081
# ## Training model #1 ##
# ## Testing model #1 ##
# Test Results: loss=0.789679, acc=0.497041

# %%
# Showing the losses with logarithmic scale on vanilla embedding
array_type = np.array(losses)
labels = ['Google w2v', 'Vanilla Embedding']
colors = ['r', 'g', 'y', 'c', 'm']
plt.yscale('log')
plt.xlabel(labels[0])
plt.ylabel(labels[1])
plt.plot([array_type.min(), array_type.max()], [array_type.min(), array_type.max()])

for i, show_array in enumerate(array_type):
    show_array = np.array(show_array).T

    plt.plot(show_array[:, 0], show_array[:, 1], colors[i]+'.', label=datasets[i])

plt.show()
plt.legend()
